# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/jbrownlee/Datasets/master/glass.csv',names=['RI','Na','Mg','AI','Si','K','Ca','Ba','Fe','Type Of Glass'])
df
# Out:
#           RI     Na    Mg    AI     Si     K    Ca    Ba   Fe  Type Of Glass
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0              1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0              1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0              1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0              1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0              1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...            ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0              7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0              7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0              7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0              7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0              7
#
# [214 rows x 10 columns]

# %%
df.head(5)
# Out:
#         RI     Na    Mg    AI     Si     K    Ca   Ba   Fe  Type Of Glass
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0              1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0              1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0              1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0              1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0              1

# %%
df.tail(5)
# Out:
#           RI     Na   Mg    AI     Si     K    Ca    Ba   Fe  Type Of Glass
# 209  1.51623  14.14  0.0  2.88  72.61  0.08  9.18  1.06  0.0              7
# 210  1.51685  14.92  0.0  1.99  73.06  0.00  8.40  1.59  0.0              7
# 211  1.52065  14.36  0.0  2.02  73.42  0.00  8.44  1.64  0.0              7
# 212  1.51651  14.38  0.0  1.94  73.61  0.00  8.48  1.57  0.0              7
# 213  1.51711  14.23  0.0  2.08  73.36  0.00  8.62  1.67  0.0              7

# %%
df.sample(5)
# Out:
#           RI     Na    Mg    AI     Si     K    Ca   Ba    Fe  Type Of Glass
# 7    1.51756  13.15  3.61  1.05  73.24  0.57  8.24  0.0  0.00              1
# 118  1.51673  13.30  3.64  1.53  72.53  0.65  8.03  0.0  0.29              2
# 46   1.51869  13.19  3.37  1.18  72.72  0.57  8.83  0.0  0.16              1
# 9    1.51755  13.00  3.60  1.36  72.99  0.57  8.40  0.0  0.11              1
# 25   1.51764  12.98  3.54  1.21  73.00  0.65  8.53  0.0  0.00              1

# %%
df.columns
# Out:
# Index(['RI', 'Na', 'Mg', 'AI', 'Si', 'K', 'Ca', 'Ba', 'Fe', 'Type Of Glass'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   RI             214 non-null    float64
#  1   Na             214 non-null    float64
#  2   Mg             214 non-null    float64
#  3   AI             214 non-null    float64
#  4   Si             214 non-null    float64
#  5   K              214 non-null    float64
#  6   Ca             214 non-null    float64
#  7   Ba             214 non-null    float64
#  8   Fe             214 non-null    float64
#  9   Type Of Glass  214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %% [markdown]
# 1. Total 213 row & 10 columns & all dataset exhibits 2type of dataset which is float64 & int64
# 2. Checking info there is no null data in this dataset
# 3.To confirm no Nulldata leats use HeatMap

# %%
df.isnull().sum()
# Out:
# RI               0
# Na               0
# Mg               0
# AI               0
# Si               0
# K                0
# Ca               0
# Ba               0
# Fe               0
# Type Of Glass    0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df['Type Of Glass'].unique()
# Out:
# array([1, 2, 3, 5, 6, 7], dtype=int64)

# %% [markdown]
# •	1- building_windows_float_processed
# •	2- building_windows_non_float_processed
# •	3- vehicle_windows_float_processed
# •	4- vehicle_windows_non_float_processed (none in this database)
# •	5- containers
# •	6- tableware
# •	7- headlamps

# %%
df['Type Of Glass'].nunique()
# Out:
# 6

# %%
for i in df.columns:
    print (df[i].value_counts)
    print ('\n')
# Out:
# <bound method IndexOpsMixin.value_counts of 0      1.52101
# 1      1.51761
# 2      1.51618
# 3      1.51766
# 4      1.51742
#         ...
# 209    1.51623
# 210    1.51685
# 211    1.52065
# 212    1.51651
# 213    1.51711
# Name: RI, Length: 214, dtype: float64>
#
#
# <bound method IndexOpsMixin.value_counts of 0      13.64
# 1      13.89
# 2      13.53
# 3      13.21
# 4      13.27
#        ...
# 209    14.14
# 210    14.92
# 211    14.36
# 212    14.38
# 213    14.23
# Name: Na, Length: 214, dtype: float64>
#
#
# <bound method IndexOpsMixin.value_counts of 0      4.49
# 1      3.60
# 2      3.55
# 3      3.69
# 4      3.62
#        ...
# 209    0.00
# 210    0.00
# 211    0.00
# 212    0.00
# 213    0.00
# Name: Mg, Length: 214, dtype: float64>
#
#
# <bound method IndexOpsMixin.value_counts of 0      1.10
# 1      1.36
# 2      1.54
# 3      1.29
# 4      1.24
#        ...
# 209    2.88
# 210    1.99
# 211    2.02
# 212    1.94
# 213    2.08
# ...

# %% [markdown]
# As I have analyzed the dataset, it appears that the distinctiveness in values is relatively low across all columns. so i can predict this problem might be a consider as a Classification problem

# %%
df.describe()
# Out:
#                RI          Na          Mg          AI          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe  Type Of Glass
# count  214.000000  214.000000  214.000000     214.000000
# mean     8.956963    0.175047    0.057009       2.780374
# std      1.423153    0.497219    0.097439       2.103739
# ...

# %% [markdown]
# 1. All columns should have a data count of 214
# 2. All columns exhibit a symmetrical data distribution, indicated by the equality of the mean and median (50%).
# 3. In the Na and Ca columns, there are outliers evident, as suggested by the notable deviation between the 75th percentile and the maximum data point

# %% [markdown]
# # Correlation Check

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# 1. I've observed a positive correlation between Type of Glass and the elements Na, Al, and Ba.
# 2. Mg shows very negative Correlation with Type of Glass.
# 3. Also RI , K and Ca shows some Nutral correlation with Type of Glass

# %% [markdown]
# # Univariate analysis

# %%
df.plot (kind='box',subplots=True, layout =(5,5), figsize=(20,25) )
# Out:
# RI                  Axes(0.125,0.747241;0.133621x0.132759)
# Na               Axes(0.285345,0.747241;0.133621x0.132759)
# Mg                Axes(0.44569,0.747241;0.133621x0.132759)
# AI               Axes(0.606034,0.747241;0.133621x0.132759)
# Si               Axes(0.766379,0.747241;0.133621x0.132759)
# K                   Axes(0.125,0.587931;0.133621x0.132759)
# Ca               Axes(0.285345,0.587931;0.133621x0.132759)
# Ba                Axes(0.44569,0.587931;0.133621x0.132759)
# Fe               Axes(0.606034,0.587931;0.133621x0.132759)
# Type Of Glass    Axes(0.766379,0.587931;0.133621x0.132759)
# dtype: object

# %%
print (df['Type Of Glass'].value_counts())
sns.countplot(df,x='Type Of Glass')
# Out:
# 2    76
# 1    70
# 7    29
# 3    17
# 5    13
# 6     9
# Name: Type Of Glass, dtype: int64
# <Axes: xlabel='Type Of Glass', ylabel='count'>

# %%
sns.histplot(df,x='Na',bins=10)
# Out:
# <Axes: xlabel='Na', ylabel='Count'>

# %%
sns.displot(df['AI'])

# %%
plt.figure(figsize=(25,20))
p=1
for i in df.columns:
    if p<=10:
        plt.subplot(5,5,p)
        sns.distplot(df[i])
        plt.xlabel(i,fontsize=15)
    p+=1
plt.show()

# %% [markdown]
# I've noticed left-skewed data points in Ca, Ba, and K. To validate this observation, I need to examine the skewness of the dataset

# %% [markdown]
# # Bivariate Analysis

# %%
sns.scatterplot(df,x='RI',y='Ca',hue='Type Of Glass',palette='bright')                 #High Positive relation in between
# Out:
# <Axes: xlabel='RI', ylabel='Ca'>

# %%
sns.scatterplot(df,x='RI', y='Si',palette='bright')                               #High Negative relation in between
# Out:
# <Axes: xlabel='RI', ylabel='Si'>

# %%
sns.pairplot(df)

# %% [markdown]
# # Remove Outliers

# %%
import scipy
from scipy.stats import zscore

# %%
z=np.abs (zscore(df))
pd.DataFrame(z)
# Out:
#            RI        Na        Mg        AI        Si         K        Ca  \
# 0    0.872868  0.284953  1.254639  0.692442  1.127082  0.671705  0.145766
# 1    0.249333  0.591817  0.636168  0.170460  0.102319  0.026213  0.793734
# 2    0.721318  0.149933  0.601422  0.190912  0.438787  0.164533  0.828949
# 3    0.232831  0.242853  0.698710  0.310994  0.052974  0.112107  0.519052
# 4    0.312045  0.169205  0.650066  0.411375  0.555256  0.081369  0.624699
# ..        ...       ...       ...       ...       ...       ...       ...
# 209  0.704815  0.898681  1.865511  2.881125  0.052974  0.640968  0.157088
# 210  0.500178  1.856097  1.865511  1.094342  0.529374  0.763919  0.392276
# 211  0.754046  1.168721  1.865511  1.154570  0.995252  0.763919  0.364103
# 212  0.612399  1.193270  1.865511  0.993960  1.241133  0.763919  0.335931
# 213  0.414363  1.009152  1.865511  1.275028  0.917606  0.763919  0.237327
#
#            Ba        Fe  Type Of Glass
# 0    0.352877  0.586451       0.848275
# ...

# %%
thresold=3
print (np.where(z>3))
# Out:
# (array([105, 106, 106, 106, 106, 106, 107, 107, 107, 110, 111, 112, 112,
#        131, 145, 162, 163, 163, 163, 171, 171, 172, 172, 174, 184, 184,
#        188, 189, 201, 201, 203, 207, 213], dtype=int64), array([6, 0, 1, 4, 6, 7, 0, 4, 6, 6, 6, 0, 6, 6, 8, 8, 3, 4, 7, 3, 5, 3,
#        5, 8, 1, 4, 4, 7, 4, 5, 7, 7, 7], dtype=int64))

# %%
print (z.iloc[105,6])                                              
print (z.iloc[106,0])
# Out:
# 3.01659640155971
# 4.252673357413172

# %% [markdown]
# 1. Inspect the data point and verify the existence of the outlier.
# 2. I need to address the outliers through imputation and store the adjusted dataset in a new variable

# %%
df_new=df[(z<3).all(axis=1)]
df=df_new
df
# Out:
#           RI     Na    Mg    AI     Si     K    Ca    Ba   Fe  Type Of Glass
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0              1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0              1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0              1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0              1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0              1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...            ...
# 208  1.51640  14.37  0.00  2.74  72.85  0.00  9.45  0.54  0.0              7
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0              7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0              7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0              7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0              7
#
# [194 rows x 10 columns]

# %%
plt.figure(figsize=(25,20))
p=1
for i in df.columns:
    if p<=10:
        plt.subplot(5,5,p)
        sns.distplot(df[i])
        plt.xlabel(i,fontsize=15)
    p+=1
plt.show()

# %% [markdown]
# Re-evaluating the distribution of data points, it appears to exhibit a well-balanced and symmetrical datapoints.

# %% [markdown]
# # Checking Skewness

# %%
df.skew()
# Out:
# RI               0.952733
# Na               0.371482
# Mg              -1.528849
# AI               0.658259
# Si              -0.425450
# K                0.303175
# Ca               1.077962
# Ba               3.188587
# Fe               1.486479
# Type Of Glass    1.284007
# dtype: float64

# %% [markdown]
# I've identified certain datapoints with significant skewness; I need to remove this skewness.

# %%
list=['Mg','Ba','Fe']
for i in list:
    df[i]=np.cbrt(df[i])

# %%
df.skew()
# Out:
# RI               0.952733
# Na               0.371482
# Mg              -2.025641
# AI               0.658259
# Si              -0.425450
# K                0.303175
# Ca               1.077962
# Ba               1.901999
# Fe               0.764874
# Type Of Glass    1.284007
# dtype: float64

# %% [markdown]
# # Scaling Dataset

# %%
from sklearn.preprocessing import StandardScaler

# %%
x=df.iloc[:,0:-1]
y=df.iloc[:,-1]

print (x,y)
# Out:
#           RI     Na        Mg    AI     Si     K    Ca        Ba   Fe
# 0    1.52101  13.64  1.133323  1.10  71.78  0.06  8.75  0.000000  0.0
# 1    1.51761  13.89  1.112650  1.36  72.73  0.48  7.83  0.000000  0.0
# 2    1.51618  13.53  1.111354  1.54  72.99  0.39  7.78  0.000000  0.0
# 3    1.51766  13.21  1.114942  1.29  72.61  0.57  8.22  0.000000  0.0
# 4    1.51742  13.27  1.113164  1.24  73.08  0.55  8.07  0.000000  0.0
# ..       ...    ...       ...   ...    ...   ...   ...       ...  ...
# 208  1.51640  14.37  0.000000  2.74  72.85  0.00  9.45  0.949947  0.0
# 209  1.51623  14.14  0.000000  2.88  72.61  0.08  9.18  1.004868  0.0
# 210  1.51685  14.92  0.000000  1.99  73.06  0.00  8.40  1.039401  0.0
# 211  1.52065  14.36  0.000000  2.02  73.42  0.00  8.44  1.042086  0.0
# 212  1.51651  14.38  0.000000  1.94  73.61  0.00  8.48  1.038305  0.0
#
# [194 rows x 9 columns] 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 208    7
# 209    7
# 210    7
# 211    7
# ...

# %%
scale=StandardScaler()
x=pd.DataFrame(scale.fit_transform(x),columns=x.columns)
x
# Out:
#            RI        Na        Mg        AI        Si         K        Ca  \
# 0    1.291781  0.332127  0.485159 -0.729105 -1.612464 -1.319609 -0.075653
# 1   -0.197832  0.704398  0.431973 -0.141722  0.016082  0.172091 -1.008147
# 2   -0.824346  0.168328  0.428639  0.264928  0.461790 -0.147559 -1.058826
# 3   -0.175926 -0.308179  0.437869 -0.299864 -0.189629  0.491741 -0.612851
# 4   -0.281075 -0.218834  0.433295 -0.412822  0.616073  0.420708 -0.764888
# ..        ...       ...       ...       ...       ...       ...       ...
# 189 -0.727959  1.419158 -2.430511  2.975928  0.221793 -1.532708  0.633854
# 190 -0.802440  1.076668 -2.430511  3.292211 -0.189629 -1.248575  0.360187
# 191 -0.530805  2.238153 -2.430511  1.281553  0.581788 -1.532708 -0.430406
# 192  1.134057  1.404267 -2.430511  1.349328  1.198921 -1.532708 -0.389863
# 193 -0.679766  1.434048 -2.430511  1.168595  1.524630 -1.532708 -0.349320
#
#            Ba        Fe
# 0   -0.434417 -0.692302
# 1   -0.434417 -0.692302
# ...

# %%
x.shape
# Out:
# (194, 9)

# %%
y.shape
# Out:
# (194,)

# %% [markdown]
# # VIF Checking

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif=pd.DataFrame()
vif['VIF Factor']=[variance_inflation_factor (x.values,i) for i in range (len (x.columns))]
vif['Features']=x.columns
vif
# Out:
#    VIF Factor Features
# 0    5.073244       RI
# 1    5.070227       Na
# 2    6.670204       Mg
# 3    2.776488       AI
# 4    3.937180       Si
# 5    3.229673        K
# 6    5.165593       Ca
# 7    2.411489       Ba
# 8    1.054204       Fe

# %% [markdown]
# I have observed the absence of multicollinearity in this dataset.

# %% [markdown]
# # OVERSAMPLING (SMOTE)

# %%
import imblearn

from imblearn.over_sampling import SMOTE

# %%
sm=SMOTE()
x_new,y_new=sm.fit_resample(x,y)
print (x_new.shape)
print (y_new.shape)
# Out:
# (420, 9)
# (420,)

# %%
x,y=x_new,y_new

# %%
y.value_counts()
# Out:
# 1    70
# 2    70
# 3    70
# 5    70
# 6    70
# 7    70
# Name: Type Of Glass, dtype: int64

# %% [markdown]
# # Model Buildup

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.ensemble import RandomForestClassifier

# %%
maxAcc=0
maxRE=0
for i in range (1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=i)
    rc=RandomForestClassifier()
    rc.fit (x_train,y_train)
    pred_rc=rc.predict(x_test)
    acc=accuracy_score(pred_rc,y_test)
    if acc>maxAcc:
        maxAcc=acc
        maxRE=i
        
print ("Best Accuracy Score:",maxAcc,"Best Random Estate Score:",maxRE)
# Out:
# Best Accuracy Score: 0.9761904761904762 Best Random Estate Score: 187

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix,roc_curve

from sklearn.model_selection import cross_val_score

# %%
def classificationModel(model):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=187)
    model.fit (x_train,y_train)
    print ('Model Traning Score:',model.score(x_train,y_train))
    pred_model=model.predict (x_test)
    print ('\n')
    
    print ("Best Accuracy Score:", accuracy_score(pred_model,y_test))
    print  ("Classification Report:",classification_report(pred_model,y_test))
    print ("Confusion Matrix:",confusion_matrix(pred_model,y_test))
    print ('\n')
    
    
    score=cross_val_score(model,x,y,cv=7)
    print ("CV Score:", np.mean(score))
    print ("Difference Between accuracy score and cv score:", accuracy_score(pred_model,y_test) - np.mean(score))

# %%
model=LogisticRegression()                                                    #Accuracy Score: 0.89
classificationModel(model)                                                    # CV Score: 0.83
                                                                              # Model Traning Score : 0.84
# Out:
# Model Traning Score: 0.8469387755102041
#
#
# Best Accuracy Score: 0.8968253968253969
# Classification Report:               precision    recall  f1-score   support
#
#            1       0.81      0.76      0.79        17
#            2       0.55      0.79      0.65        14
#            3       0.95      0.83      0.89        24
#            5       1.00      0.96      0.98        24
#            6       1.00      1.00      1.00        25
#            7       1.00      0.95      0.98        22
#
#     accuracy                           0.90       126
#    macro avg       0.89      0.88      0.88       126
# weighted avg       0.92      0.90      0.90       126
#
# Confusion Matrix: [[13  4  0  0  0  0]
#  [ 2 11  1  0  0  0]
#  [ 1  3 20  0  0  0]
#  [ 0  1  0 23  0  0]
#  [ 0  0  0  0 25  0]
#  [ 0  1  0  0  0 21]]
#
#
# CV Score: 0.838095238095238
# Difference Between accuracy score and cv score: 0.058730158730158855

# %%
model=SVC()                                                                   #Accuracy Score: 0.90
classificationModel(model)                                                    # CV Score: 0.85
                                                                              # Model Traning Score : 0.88
# Out:
# Model Traning Score: 0.8809523809523809
#
#
# Best Accuracy Score: 0.9047619047619048
# Classification Report:               precision    recall  f1-score   support
#
#            1       0.81      0.72      0.76        18
#            2       0.70      0.78      0.74        18
#            3       0.86      0.86      0.86        21
#            5       1.00      1.00      1.00        23
#            6       1.00      1.00      1.00        25
#            7       1.00      1.00      1.00        21
#
#     accuracy                           0.90       126
#    macro avg       0.89      0.89      0.89       126
# weighted avg       0.91      0.90      0.90       126
#
# Confusion Matrix: [[13  4  1  0  0  0]
#  [ 2 14  2  0  0  0]
#  [ 1  2 18  0  0  0]
#  [ 0  0  0 23  0  0]
#  [ 0  0  0  0 25  0]
#  [ 0  0  0  0  0 21]]
#
#
# CV Score: 0.8595238095238097
# Difference Between accuracy score and cv score: 0.04523809523809508

# %%
model=GradientBoostingClassifier()                                            #Accuracy Score: 0.95
classificationModel(model)                                                    # CV Score: 0.87
                                                                              # Model Traning Score : 1.0
# Out:
# Model Traning Score: 1.0
#
#
# Best Accuracy Score: 0.9523809523809523
# Classification Report:               precision    recall  f1-score   support
#
#            1       0.75      0.86      0.80        14
#            2       0.95      0.90      0.93        21
#            3       0.95      0.91      0.93        22
#            5       1.00      1.00      1.00        23
#            6       1.00      1.00      1.00        25
#            7       1.00      1.00      1.00        21
#
#     accuracy                           0.95       126
#    macro avg       0.94      0.95      0.94       126
# weighted avg       0.96      0.95      0.95       126
#
# Confusion Matrix: [[12  1  1  0  0  0]
#  [ 2 19  0  0  0  0]
#  [ 2  0 20  0  0  0]
#  [ 0  0  0 23  0  0]
#  [ 0  0  0  0 25  0]
#  [ 0  0  0  0  0 21]]
#
#
# CV Score: 0.8738095238095239
# Difference Between accuracy score and cv score: 0.0785714285714284

# %%
model=BaggingClassifier()                                                     #Accuracy Score: 0.94
classificationModel(model)                                                    # CV Score: 0.86
                                                                              # Model Traning Score : 0.99
# Out:
# Model Traning Score: 0.9931972789115646
#
#
# Best Accuracy Score: 0.9444444444444444
# Classification Report:               precision    recall  f1-score   support
#
#            1       0.81      0.81      0.81        16
#            2       0.80      0.89      0.84        18
#            3       1.00      0.91      0.95        23
#            5       1.00      1.00      1.00        23
#            6       1.00      1.00      1.00        25
#            7       1.00      1.00      1.00        21
#
#     accuracy                           0.94       126
#    macro avg       0.94      0.94      0.93       126
# weighted avg       0.95      0.94      0.95       126
#
# Confusion Matrix: [[13  3  0  0  0  0]
#  [ 2 16  0  0  0  0]
#  [ 1  1 21  0  0  0]
#  [ 0  0  0 23  0  0]
#  [ 0  0  0  0 25  0]
#  [ 0  0  0  0  0 21]]
#
#
# CV Score: 0.8619047619047618
# Difference Between accuracy score and cv score: 0.08253968253968258

# %%
model=RandomForestClassifier()                                                #Accuracy Score: 0.96
classificationModel(model)                                                    # CV Score: 0.88
                                                                              # Model Traning Score : 1.0
# Out:
# Model Traning Score: 1.0
#
#
# Best Accuracy Score: 0.9603174603174603
# Classification Report:               precision    recall  f1-score   support
#
#            1       0.81      0.87      0.84        15
#            2       0.95      0.90      0.93        21
#            3       0.95      0.95      0.95        21
#            5       1.00      1.00      1.00        23
#            6       1.00      1.00      1.00        25
#            7       1.00      1.00      1.00        21
#
#     accuracy                           0.96       126
#    macro avg       0.95      0.95      0.95       126
# weighted avg       0.96      0.96      0.96       126
#
# Confusion Matrix: [[13  1  1  0  0  0]
#  [ 2 19  0  0  0  0]
#  [ 1  0 20  0  0  0]
#  [ 0  0  0 23  0  0]
#  [ 0  0  0  0 25  0]
#  [ 0  0  0  0  0 21]]
#
#
# CV Score: 0.8880952380952379
# Difference Between accuracy score and cv score: 0.07222222222222241

# %%
model=ExtraTreesClassifier()                                                  #Accuracy Score: 0.94
classificationModel(model)                                                    # CV Score: 0.88
                                                                              # Model Traning Score : 1.0
# Out:
# Model Traning Score: 1.0
#
#
# Best Accuracy Score: 0.9444444444444444
# Classification Report:               precision    recall  f1-score   support
#
#            1       0.81      0.81      0.81        16
#            2       0.95      0.83      0.88        23
#            3       0.86      1.00      0.92        18
#            5       1.00      1.00      1.00        23
#            6       1.00      1.00      1.00        25
#            7       1.00      1.00      1.00        21
#
#     accuracy                           0.94       126
#    macro avg       0.94      0.94      0.94       126
# weighted avg       0.95      0.94      0.94       126
#
# Confusion Matrix: [[13  1  2  0  0  0]
#  [ 3 19  1  0  0  0]
#  [ 0  0 18  0  0  0]
#  [ 0  0  0 23  0  0]
#  [ 0  0  0  0 25  0]
#  [ 0  0  0  0  0 21]]
#
#
# CV Score: 0.8880952380952382
# Difference Between accuracy score and cv score: 0.05634920634920626

# %%
model=DecisionTreeClassifier()                                                #Accuracy Score: 0.89
classificationModel(model)                                                    # CV Score: 0.83
                                                                              # Model Traning Score : 1.0
# Out:
# Model Traning Score: 1.0
#
#
# Best Accuracy Score: 0.8968253968253969
# Classification Report:               precision    recall  f1-score   support
#
#            1       0.69      0.58      0.63        19
#            2       0.70      0.78      0.74        18
#            3       0.90      0.95      0.93        20
#            5       1.00      1.00      1.00        23
#            6       1.00      1.00      1.00        25
#            7       1.00      1.00      1.00        21
#
#     accuracy                           0.90       126
#    macro avg       0.88      0.88      0.88       126
# weighted avg       0.89      0.90      0.89       126
#
# Confusion Matrix: [[11  6  2  0  0  0]
#  [ 4 14  0  0  0  0]
#  [ 1  0 19  0  0  0]
#  [ 0  0  0 23  0  0]
#  [ 0  0  0  0 25  0]
#  [ 0  0  0  0  0 21]]
#
#
# CV Score: 0.838095238095238
# Difference Between accuracy score and cv score: 0.058730158730158855

# %% [markdown]
# After evaluating various classification models based on the difference in Accuracy score and cross-validation scores, RandomForestClassifier is identified as the most suitable model for the given dataset.

# %% [markdown]
# # Hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
prama={'n_estimators':[100,150,120,200],
      'criterion':['gini','entropy','log_loss'],
      'max_depth':[1,5,10,20,50]}

# %%
gscv=GridSearchCV(RandomForestClassifier(),prama,cv=7)
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=7, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [1, 5, 10, 20, 50],
#                          'n_estimators': [100, 150, 120, 200]})

# %%
gscv.best_params_
# Out:
# {'criterion': 'log_loss', 'max_depth': 20, 'n_estimators': 150}

# %% [markdown]
# # Final Model

# %%
FinalModel=RandomForestClassifier(criterion='log_loss',max_depth=20,n_estimators=150)
FinalModel.fit (x_train,y_train)
pred_FinalModel=FinalModel.predict(x_test)
print ("Model Score:",FinalModel.score(x_train,y_train))
print ('\n')
print("Best Accuracy Score:", accuracy_score(pred_FinalModel,y_test))
print ('\n')
print ("Classification Report:",classification_report(pred_FinalModel,y_test))
print ('\n')
print ("Confusion Matrix:",confusion_matrix(pred_FinalModel,y_test))
print ('\n')
print (pred_FinalModel)
print ('\n')


score =cross_val_score(FinalModel,x,y,cv=7)
print ("CV Score:",np.mean(score))
# Out:
# Model Score: 1.0
#
#
# Best Accuracy Score: 0.9365079365079365
#
#
# Classification Report:               precision    recall  f1-score   support
#
#            1       0.87      0.83      0.85        24
#            2       0.86      0.90      0.88        21
#            3       0.94      0.89      0.92        19
#            5       1.00      1.00      1.00        15
#            6       1.00      1.00      1.00        21
#            7       0.96      1.00      0.98        26
#
#     accuracy                           0.94       126
#    macro avg       0.94      0.94      0.94       126
# weighted avg       0.94      0.94      0.94       126
#
#
#
# Confusion Matrix: [[20  3  1  0  0  0]
#  [ 1 19  0  0  0  1]
#  [ 2  0 17  0  0  0]
#  [ 0  0  0 15  0  0]
#  [ 0  0  0  0 21  0]
#  [ 0  0  0  0  0 26]]
#
#
# [2 7 7 6 5 2 1 3 1 7 5 2 1 1 1 5 6 1 6 2 1 5 7 7 2 2 3 1 3 6 7 7 3 5 7 6 5
#  1 1 2 3 3 7 5 6 2 1 3 5 3 7 7 7 7 6 2 3 7 7 1 1 3 6 2 6 3 1 7 5 7 7 3 6 5
# ...

# %% [markdown]
# # Saving Model

# %%
import joblib

# %%
joblib.dump(FinalModel,'FinalModel.obj')
# Out:
# ['FinalModel.obj']

# %% [markdown]
# # Checking Final Model

# %%
FinalModel.predict(x_test)
# Out:
# array([2, 7, 7, 6, 5, 2, 1, 3, 1, 7, 5, 2, 1, 1, 1, 5, 6, 1, 6, 2, 1, 5,
#        7, 7, 2, 2, 3, 1, 3, 6, 7, 7, 3, 5, 7, 6, 5, 1, 1, 2, 3, 3, 7, 5,
#        6, 2, 1, 3, 5, 3, 7, 7, 7, 7, 6, 2, 3, 7, 7, 1, 1, 3, 6, 2, 6, 3,
#        1, 7, 5, 7, 7, 3, 6, 5, 1, 6, 5, 3, 6, 6, 2, 1, 1, 2, 1, 6, 1, 1,
#        5, 1, 7, 6, 3, 7, 2, 2, 7, 2, 2, 5, 5, 6, 2, 6, 6, 3, 2, 7, 3, 2,
#        3, 1, 7, 2, 6, 7, 5, 7, 3, 6, 1, 2, 7, 6, 3, 1], dtype=int64)

# %%
Best_Fit_Model=joblib.load('FinalModel.obj')
Best_Fit_Model
# Out:
# RandomForestClassifier(criterion='log_loss', max_depth=20, n_estimators=150)

# %% [markdown]
# # Predict Model

# %%
def predictModel(p):
    p=p.reshape (1,-1)
    pred=Best_Fit_Model.predict (p)
    print ("Predict Value",pred)
    if pred==1:
        print ("Building_windows_float_processed")
    elif pred==2:
        print ("Building_windows_non_float_processed")
    elif pred==3:
        print ("vehicle_windows_float_processed")
    elif pred == 4:
        print ("vehicle_windows_non_float_processed ")
    elif pred==5:
        print ("containers")
    elif pred== 6:
        print ("Tableware")
    else:
        print("Headlamps")

# %%
p=np.array([1.246781,2.314227,0.478959,-0.729105,-1.612464,-2.319609,-0.078953,-1.434417,-0.985302])
predictModel(p)
# Out:
# Predict Value [1]
# Building_windows_float_processed
