# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException
from bs4 import BeautifulSoup
import requests
import time

# %%
driver=webdriver.Chrome()

driver.get('https://www.flipkart.com/')

time.sleep(3)

# %%
Cross_click=driver.find_element(By.XPATH,'/html/body/div[3]/div/span')
Cross_click.click()

# %%
search_input=driver.find_element(By.XPATH,'//*[@id="container"]/div/div[1]/div/div/div/div/div[1]/div/div[1]/div/div[1]/header/div[1]/div[2]/form/div/div/input')
search_input.send_keys('Gaming Laptop')

# %%
Search_click=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div/div/div/div[1]/div/div[1]/div/div[1]/header/div[1]/div[2]/form/div/button')
Search_click.click()

# %%
Name=[]
MRP=[]
Offer_Price=[]
Processor=[]
RAM=[]
SSD=[]
Warrenty=[]
Product_URL=[]

try:
    Namee_tag=driver.find_elements(By.XPATH,'//div[@class="_4rR01T"]')
    for i in Namee_tag[0:10]:
        Name.append(i.text)
        
    MRP_tag=driver.find_elements(By.XPATH,'//div[@class="_3I9_wc _27UcVY"]')
    for i in MRP_tag[0:10]:
        MRP.append(i.text)
        
    Offer_Price_tag=driver.find_elements(By.XPATH,'//div[@class="_30jeq3 _1_WHN1"]')
    for i in Offer_Price_tag[0:10]:
        Offer_Price.append(i.text)
        
    Processor_tag=driver.find_elements(By.XPATH,'//li[@class="rgWa7D"][1]')
    for i in Processor_tag[0:10]:
        Processor.append(i.text)
        
    RAM_tag=driver.find_elements(By.XPATH,'//li[@class="rgWa7D"][2]')
    for i in RAM_tag[0:10]:
        RAM.append(i.text)
        
    SSD_tag=driver.find_elements(By.XPATH,'//li[@class="rgWa7D"][4]')
    for i in SSD_tag[0:10]:
        SSD.append(i.text)
        
    Warrenty_tag=driver.find_elements(By.XPATH,'//li[@class="rgWa7D"][6]')
    for i in Warrenty_tag[0:10]:
        Warrenty.append(i.text)
        
    Product_URL_tag=driver.find_elements(By.XPATH,'//a[@class="_1fQZEK"]')
    for i in Product_URL_tag[0:10]:
        Product_URL.append(i.get_attribute('href'))
        
        
        
        
    
        
        
    
        
        
        
    
        
        
    
        
except Exception as e:
    Name.append('No Information')
    MRP.appenda('No MRP')
    Offer_Price.appendp('No information')
    Processor.append('No information')
    RAM.append('No information')
    SSD.append('No information')
    Warrenty.append('No information')
    Product_URL.append('No Information')

# %%
import pandas as pd

# %%
df=pd.DataFrame({'Product Name':Name,'MRP':MRP,'Offer_Price':Offer_Price,'Processor':Processor,'RAM':RAM,'SSD':SSD,'Warrenty':Warrenty,'Product_URL':Product_URL})
df
# Out:
#                                         Product Name        MRP Offer_Price  \
# 0  ASUS ROG Strix G15 Ryzen 7 Octa Core 6800H - (...  ₹1,17,990     ₹83,990
# 1  ASUS TUF Gaming F15 with 90WHr Battery Core i5...    ₹89,990     ₹59,990
# 2  Lenovo IdeaPad Gaming 3 Intel Core i5 11th Gen...    ₹73,490     ₹44,990
# 3  HP Victus Ryzen 5 Hexa Core 5600H - (8 GB/512 ...    ₹63,628     ₹47,990
# 4  MSI Bravo 15 Ryzen 7 Octa Core 5800H - (16 GB/...    ₹72,990     ₹55,990
# 5  ASUS Vivobook Pro 15 For Creator, Ryzen 5 Hexa...    ₹75,990     ₹47,990
# 6  HP Victus Core i5 12th Gen 12450H - (8 GB/512 ...    ₹74,829     ₹56,990
# 7  ASUS TUF Gaming F15 - AI Powered Gaming Core i...    ₹75,990     ₹51,990
# 8  Acer Aspire 7 Core i5 12th Gen 12450H - (8 GB/...    ₹83,999     ₹49,990
# 9  Acer Aspire 7 (2023) Core i5 12th Gen 12450H -...    ₹84,999     ₹57,990
#
#                             Processor             RAM         SSD  \
# ...

# %%
driver.close()
